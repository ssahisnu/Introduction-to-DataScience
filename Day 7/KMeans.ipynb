# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.cluster import KMeans

# %%
X, y = make_blobs(n_samples=500, centers=5)#, cluster_std=0.50, random_state=0)
plt.scatter(X[:,0], X[:,1])

# %%
wcss = []
for i in range(1,21):
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,21),wcss)
plt.xlabel('No. of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
kmeans = KMeans(n_clusters=5)
model = kmeans.fit(X)
print(model.labels_)
plt.scatter(X[:,0],X[:,1])
plt.scatter(X[:,0],X[:,1],c=model.labels_.astype(float))
plt.show()
# Out:
# [4 0 4 4 2 3 2 0 0 2 1 4 0 1 4 2 1 1 4 0 3 1 4 0 0 4 1 0 4 4 3 4 4 4 3 0 2
#  3 3 0 3 4 2 3 2 0 1 4 0 4 4 0 3 2 3 2 1 1 3 4 1 3 4 2 0 3 3 0 3 3 4 3 0 3
#  4 4 2 0 4 0 0 3 1 2 2 3 3 1 3 4 1 3 2 2 2 4 0 2 1 0 4 4 3 0 4 3 4 3 4 2 0
#  2 3 2 1 2 0 3 4 2 0 3 1 4 1 1 4 3 3 0 1 1 3 2 0 2 2 4 1 0 3 3 1 2 1 4 3 1
#  2 3 4 4 0 0 1 2 4 3 3 3 0 1 1 0 0 3 1 0 2 0 1 1 0 1 2 1 4 2 2 1 0 0 1 1 0
#  2 0 0 0 1 0 3 0 0 2 1 1 3 4 0 3 4 3 0 1 1 2 0 2 0 4 1 3 0 3 3 3 1 3 3 0 0
#  4 4 2 0 0 3 2 1 3 4 1 0 2 2 3 4 2 0 0 0 4 1 2 2 3 3 0 3 4 2 2 0 3 2 2 2 4
#  0 2 4 3 0 0 1 4 2 4 2 2 1 3 1 2 1 1 3 4 3 4 4 4 1 1 1 2 2 4 2 4 3 2 0 1 1
#  4 4 3 0 3 0 4 3 1 4 2 2 4 0 3 2 2 2 2 1 3 3 2 3 2 4 1 0 3 3 1 4 2 3 3 0 0
#  1 2 3 2 0 2 1 4 4 4 0 2 1 4 4 2 2 1 1 0 2 1 1 1 2 4 4 3 4 3 1 1 0 2 4 4 2
#  4 3 2 3 3 2 1 4 0 2 0 1 1 4 4 3 4 2 0 3 0 4 3 1 1 0 3 0 1 0 1 1 0 4 3 4 3
#  1 1 2 4 1 1 2 2 1 0 1 0 4 3 1 1 2 0 3 4 2 3 2 1 0 3 3 4 4 1 4 3 3 2 0 2 3
#  0 2 1 4 0 2 2 3 1 1 2 2 0 2 0 4 4 2 4 0 4 4 1 0 1 0 4 3 0 1 0 2 3 3 4 4 0
#  1 1 3 3 0 1 1 0 2 4 2 1 4 1 0 4 3 2 1]
