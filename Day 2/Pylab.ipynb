# %%
import numpy as np
from pylab import *

# %%
x = np.linspace(-10,10,100)
y = x ** 3

# %%
figure()
plot(x,y,'--')
xlabel('x')
ylabel('y')
title('y = x ^ 2')
show()

# %%
subplot(1,2,1)
plot(x,y,'g')
subplot(1,2,2)
plot(x,y,'r')
